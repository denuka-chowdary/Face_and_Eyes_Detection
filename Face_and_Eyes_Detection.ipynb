# %%
# Haar Cascade object detection for eye and face in python using OpenCV

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !wget https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
# Out:
# --2023-05-17 10:04:28--  https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haarcascade_eye.xml’
#
# haarcascade_eye.xml     [   <=>              ]   3.64M  7.36MB/s    in 0.5s
#
# 2023-05-17 10:04:30 (7.36 MB/s) - ‘haarcascade_eye.xml’ saved [3821112]

# %%
# !wget https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2023-05-17 10:04:30--  https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal     [   <=>              ]   9.74M  15.6MB/s    in 0.6s
#
# 2023-05-17 10:04:32 (15.6 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [10211719]

# %%
# !wget https://st.depositphotos.com/1008939/1880/i/600/depositphotos_18807295-stock-photo-portrait-of-handsome-man.jpg
# Out:
# --2023-05-17 10:04:32--  https://st.depositphotos.com/1008939/1880/i/600/depositphotos_18807295-stock-photo-portrait-of-handsome-man.jpg
# Resolving st.depositphotos.com (st.depositphotos.com)... 104.99.71.58
# Connecting to st.depositphotos.com (st.depositphotos.com)|104.99.71.58|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36632 (36K) [image/jpeg]
# Saving to: ‘depositphotos_18807295-stock-photo-portrait-of-handsome-man.jpg’
#
# depositphotos_18807 100%[===================>]  35.77K  --.-KB/s    in 0.04s
#
# 2023-05-17 10:04:32 (853 KB/s) - ‘depositphotos_18807295-stock-photo-portrait-of-handsome-man.jpg’ saved [36632/36632]

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

# %%
img = cv2.imread('depositphotos_18807295-stock-photo-portrait-of-handsome-man.jpg')
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces=face_cascade.detectMultiScale(gray,1.1,8)
print(faces)
for (x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),8)

  roi_gray=gray[y:y+h,x:x+w]
  roi_color=img[y:y+h,x:x+w]

  eyes=eye_cascade.detectMultiScale(roi_gray)
  for (ex,ey,ew,eh) in eyes:
    cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),8)
# Out:
# [[160 136 283 283]]

# %%
plt.imshow(img)
plt.show()
